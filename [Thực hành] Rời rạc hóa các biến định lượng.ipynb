# %%
import pandas as pd
import numpy as np

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

# %%
# định nghĩa khoảng giá trị các nhóm
bins = [18, 25, 35, 60, 100]

# %%
# thực hiện rời rạc hóa
cats = pd.cut(ages, bins)

# %%
cats
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
# lấy ra index của nhóm tương ứng với các phần tử
cats.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
# lấy ra các nhóm
cats.categories
# Out:
# IntervalIndex([(18, 25], (25, 35], (35, 60], (60, 100]], dtype='interval[int64, right]')

# %%
# thống kê số lượng phần tử ở mỗi nhóm
pd.value_counts(cats)
# Out:
# <ipython-input-8-042dcd16acc7>:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(cats)
# (18, 25]     5
# (25, 35]     3
# (35, 60]     3
# (60, 100]    1
# Name: count, dtype: int64

# %%
pd.cut(ages, [18, 26, 36, 61, 100], right=False)
# Out:
# [[18, 26), [18, 26), [18, 26), [26, 36), [18, 26), ..., [26, 36), [61, 100), [36, 61), [36, 61), [26, 36)]
# Length: 12
# Categories (4, interval[int64, left]): [[18, 26) < [26, 36) < [36, 61) < [61, 100)]

# %%
# danh sách nhãn
group_names = ['Youth', 'YoungAdult', 'MiddleAged', 'Senior']

pd.cut(ages, bins, labels=group_names)
# Out:
# ['Youth', 'Youth', 'Youth', 'YoungAdult', 'Youth', ..., 'YoungAdult', 'Senior', 'MiddleAged', 'MiddleAged', 'YoungAdult']
# Length: 12
# Categories (4, object): ['Youth' < 'YoungAdult' < 'MiddleAged' < 'Senior']

# %%
# sinh dữ liệu ngẫu nhiên gồm 20 phần tử
data = np.random.rand(20)

# %%
cut_data = pd.cut(data, 4, precision=2)
cut_data
# Out:
# [(0.25, 0.46], (0.035, 0.25], (0.25, 0.46], (0.46, 0.68], (0.68, 0.89], ..., (0.25, 0.46], (0.46, 0.68], (0.46, 0.68], (0.46, 0.68], (0.25, 0.46]]
# Length: 20
# Categories (4, interval[float64, right]): [(0.035, 0.25] < (0.25, 0.46] < (0.46, 0.68] <
#                                            (0.68, 0.89]]

# %%
pd.value_counts(cut_data)
# Out:
# <ipython-input-13-1d99f1c849eb>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(cut_data)
# (0.46, 0.68]     7
# (0.25, 0.46]     5
# (0.035, 0.25]    4
# (0.68, 0.89]     4
# Name: count, dtype: int64

# %%
 # sinh ngẫu nhiễn 1000 điểm dữ liệu
 data = np.random.randn(1000)

# %%
# thực hiện hàm qcut trên dữ liệu vừa sinh ra
cats = pd.qcut(data, 4)

# %%
cats
# Out:
# [(-3.295, -0.655], (-0.655, -0.0417], (-0.0417, 0.612], (0.612, 3.564], (-3.295, -0.655], ..., (0.612, 3.564], (-0.655, -0.0417], (-0.0417, 0.612], (-0.655, -0.0417], (-3.295, -0.655]]
# Length: 1000
# Categories (4, interval[float64, right]): [(-3.295, -0.655] < (-0.655, -0.0417] < (-0.0417, 0.612] <
#                                            (0.612, 3.564]]

# %%
#thống kê số lượng phần tử
pd.value_counts(cats)
# Out:
# <ipython-input-17-d1a46bb072e6>:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(cats)
# (-3.295, -0.655]     250
# (-0.655, -0.0417]    250
# (-0.0417, 0.612]     250
# (0.612, 3.564]       250
# Name: count, dtype: int64

# %%
pd.qcut(data, [0, 0.1, 0.5, 0.9, 1.])
# Out:
# [(-1.307, -0.0417], (-1.307, -0.0417], (-0.0417, 1.326], (-0.0417, 1.326], (-3.295, -1.307], ..., (1.326, 3.564], (-1.307, -0.0417], (-0.0417, 1.326], (-1.307, -0.0417], (-1.307, -0.0417]]
# Length: 1000
# Categories (4, interval[float64, right]): [(-3.295, -1.307] < (-1.307, -0.0417] < (-0.0417, 1.326] <
#                                            (1.326, 3.564]]
